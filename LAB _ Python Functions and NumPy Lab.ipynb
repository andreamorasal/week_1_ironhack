# %%
import numpy as np

# %%
# Lab 1: Simple Greeting Function
def greet(name):
    print(f"Hello, {name}!")
 
greet("Alice")
greet("Bob")
# Out:
# Hello, Alice!
# Hello, Bob!

# %%
#Lab 2: Add Two Numbers

def add_numbers(a, b):
    return a + b
 
result = add_numbers(15, 27)
print(result)
# Out:
# 42

# %%
#Lab 3: BMI Calculator (Function with Return)
def calculate_bmi(weight_kg, height_m):
    bmi = weight_kg / (height_m ** 2)
    return round(bmi, 2)
 
print(calculate_bmi(70, 1.75))
# Out:
# 22.86

# %%
#Billing Calculator with Default Arguments


def calculate_total(amount, tax_rate=0.05):
    return amount * (1 + tax_rate)
 
print(f"Total: {calculate_total(100):.2f}")
print(f"Total: {calculate_total(200, 0.12):.2f}")
# Out:
# Total: 105.00
# Total: 224.00

# %%
#Lab 5: Function Naming and Docstring — Discount Calculator
def apply_discount(price, discount_percent):
    """Return price after applying discount_percent (e.g., 10 for 10%)."""
    return price * (1 - discount_percent / 100)
 
print(apply_discount(250, 10))
# Out:
# 225.0

# %%
#Lab 6: Reusable Utility — Normalize Names
def normalize_name(name):
    """
    Strip whitespace, collapse multiple spaces,
    and convert to title case.
    """
    cleaned = ' '.join(name.strip().split())
    return cleaned.title()
 
print(normalize_name("  alice   johnson "))
print(normalize_name("BOB mcDONALD"))
# Out:
# Alice Johnson
# Bob Mcdonald

# %%
#Lab 7: Function Returning Multiple Values — Basic Stats

def basic_stats(numbers):
    count = len(numbers)
    total = sum(numbers)
    mean = total / count if count > 0 else None
    return count, total, mean
 
cnt, tot, mean = basic_stats([10, 20, 30])
print("Count:", cnt)
print("Total:", tot)
print("Mean:", mean)
# Out:
# Count: 3
# Total: 60
# Mean: 20.0

# %%
#Lab 8: Apply Function to a List of Amounts — apply_tax
def apply_tax(amounts, tax_rate=0.1):
    taxed = []
    for amt in amounts:
        taxed.append(round(amt * (1 + tax_rate), 2))
    return taxed
 
amounts = [100, 200, 350]
print(apply_tax(amounts, 0.05))
print("Original unchanged:", amounts)
# Out:
# [105.0, 210.0, 367.5]
# Original unchanged: [100, 200, 350]

# %%
#Lab 9: Function with Optional Argument and Simple Validation
def process_score(score, max_score=100):
    if score < 0 or score > max_score:
        return None
    percent = (score / max_score) * 100
    return round(percent, 1)
 
print(process_score(85))
print(process_score(150))
# Out:
# 85.0
# None

# %%
#Lab 10: NumPy — Create Arrays

import numpy as np
 
py_list = [10, 20, 30, 40, 50]
arr = np.array(py_list)
print(arr)
print(arr.dtype)
# Out:
# [10 20 30 40 50]
# int32

# %%
#Lab 11: Array Indexing and Slicing
import numpy as np
 
arr = np.array([10, 20, 30, 40, 50])
first = arr[0]
last = arr[-1]
slice_1_4 = arr[1:4]
 
print("First:", first)
print("Last:", last)
print("Slice 1:4 ->", slice_1_4)
# Out:
# First: 10
# Last: 50
# Slice 1:4 -> [20 30 40]

# %%
#Lab 12: Array Filtering (Boolean Masks)
import numpy as np
 
sales = np.array([120, 250, 90, 400, 60])
mask = sales > 100
high_sales = sales[mask]
print(high_sales)
print("Count >100:", high_sales.size)
# Out:
# [120 250 400]
# Count >100: 3
